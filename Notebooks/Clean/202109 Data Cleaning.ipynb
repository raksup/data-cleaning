# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('202109-divvy-tripdata.csv')
df.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  9DC7B962304CBFD8  electric_bike  2021-09-28 16:07:10  2021-09-28 16:09:54
# 1  F930E2C6872D6B32  electric_bike  2021-09-28 14:24:51  2021-09-28 14:40:05
# 2  6EF72137900BB910  electric_bike  2021-09-28 00:20:16  2021-09-28 00:23:57
# 3  78D1DE133B3DBF55  electric_bike  2021-09-28 14:51:17  2021-09-28 15:00:06
# 4  E03D4ACDCAEF6E00  electric_bike  2021-09-28 09:53:12  2021-09-28 10:03:44
#
#   start_station_name start_station_id end_station_name end_station_id  \
# 0                NaN              NaN              NaN            NaN
# 1                NaN              NaN              NaN            NaN
# 2                NaN              NaN              NaN            NaN
# 3                NaN              NaN              NaN            NaN
# 4                NaN              NaN              NaN            NaN
#
#    start_lat  start_lng  end_lat  end_lng member_casual
# ...

# %%
df = df.drop(columns=['start_station_name', 'start_station_id', 'end_station_name', 'end_station_id',
                     'end_station_id', 'start_lat','start_lng', 'end_lat', 'end_lng'])
df.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  9DC7B962304CBFD8  electric_bike  2021-09-28 16:07:10  2021-09-28 16:09:54
# 1  F930E2C6872D6B32  electric_bike  2021-09-28 14:24:51  2021-09-28 14:40:05
# 2  6EF72137900BB910  electric_bike  2021-09-28 00:20:16  2021-09-28 00:23:57
# 3  78D1DE133B3DBF55  electric_bike  2021-09-28 14:51:17  2021-09-28 15:00:06
# 4  E03D4ACDCAEF6E00  electric_bike  2021-09-28 09:53:12  2021-09-28 10:03:44
#
#   member_casual
# 0        casual
# 1        casual
# 2        casual
# 3        casual
# 4        casual

# %%
df['started_at']= pd.to_datetime(df['started_at'])
df['ended_at']= pd.to_datetime(df['ended_at'])

# %%
if df['started_at'].any() > df['ended_at'].any():
    print('issues in date present')

# %%
df['duration'] = (df['ended_at'] - df['started_at'])
df.head()
# Out:
#             ride_id  rideable_type          started_at            ended_at  \
# 0  9DC7B962304CBFD8  electric_bike 2021-09-28 16:07:10 2021-09-28 16:09:54
# 1  F930E2C6872D6B32  electric_bike 2021-09-28 14:24:51 2021-09-28 14:40:05
# 2  6EF72137900BB910  electric_bike 2021-09-28 00:20:16 2021-09-28 00:23:57
# 3  78D1DE133B3DBF55  electric_bike 2021-09-28 14:51:17 2021-09-28 15:00:06
# 4  E03D4ACDCAEF6E00  electric_bike 2021-09-28 09:53:12 2021-09-28 10:03:44
#
#   member_casual        duration
# 0        casual 0 days 00:02:44
# 1        casual 0 days 00:15:14
# 2        casual 0 days 00:03:41
# 3        casual 0 days 00:08:49
# 4        casual 0 days 00:10:32

# %%
day_of_week = []

for i in df['started_at']:
    a = i.weekday()
    day_of_week.append(a)
df['day_of_week'] = day_of_week
df.head()
# Out:
#             ride_id  rideable_type          started_at            ended_at  \
# 0  9DC7B962304CBFD8  electric_bike 2021-09-28 16:07:10 2021-09-28 16:09:54
# 1  F930E2C6872D6B32  electric_bike 2021-09-28 14:24:51 2021-09-28 14:40:05
# 2  6EF72137900BB910  electric_bike 2021-09-28 00:20:16 2021-09-28 00:23:57
# 3  78D1DE133B3DBF55  electric_bike 2021-09-28 14:51:17 2021-09-28 15:00:06
# 4  E03D4ACDCAEF6E00  electric_bike 2021-09-28 09:53:12 2021-09-28 10:03:44
#
#   member_casual        duration  day_of_week
# 0        casual 0 days 00:02:44            1
# 1        casual 0 days 00:15:14            1
# 2        casual 0 days 00:03:41            1
# 3        casual 0 days 00:08:49            1
# 4        casual 0 days 00:10:32            1

# %%
df.tail()
# Out:
#                  ride_id  rideable_type          started_at  \
# 756142  FA66BCAB0D73DDC2   classic_bike 2021-09-22 15:46:57
# 756143  1D44DEFB5D36CA04   classic_bike 2021-09-25 16:25:23
# 756144  6A346EA57FC23C45   classic_bike 2021-09-25 16:26:05
# 756145  49360AFD771100A6   classic_bike 2021-09-15 17:57:48
# 756146  343190A2DC023FED  electric_bike 2021-09-11 18:01:06
#
#                   ended_at member_casual        duration  day_of_week
# 756142 2021-09-22 16:01:15        casual 0 days 00:14:18            2
# 756143 2021-09-25 16:40:29        casual 0 days 00:15:06            5
# 756144 2021-09-25 16:40:30        casual 0 days 00:14:25            5
# 756145 2021-09-15 18:24:06        casual 0 days 00:26:18            2
# 756146 2021-09-11 18:08:26        member 0 days 00:07:20            5

# %%
df['member_casual'].describe()
# Out:
# count     756147
# unique         2
# top       member
# freq      392257
# Name: member_casual, dtype: object

# %%
df.to_excel('202109 Cyclistic Data Processed.xlsx')

# %%
df['duration_minutes'] = (df['ended_at'] - df['started_at']).dt.total_seconds() / 60
df.head()
# Out:
#             ride_id  rideable_type          started_at            ended_at  \
# 0  9DC7B962304CBFD8  electric_bike 2021-09-28 16:07:10 2021-09-28 16:09:54
# 1  F930E2C6872D6B32  electric_bike 2021-09-28 14:24:51 2021-09-28 14:40:05
# 2  6EF72137900BB910  electric_bike 2021-09-28 00:20:16 2021-09-28 00:23:57
# 3  78D1DE133B3DBF55  electric_bike 2021-09-28 14:51:17 2021-09-28 15:00:06
# 4  E03D4ACDCAEF6E00  electric_bike 2021-09-28 09:53:12 2021-09-28 10:03:44
#
#   member_casual        duration  day_of_week  duration_minutes
# 0        casual 0 days 00:02:44            1          2.733333
# 1        casual 0 days 00:15:14            1         15.233333
# 2        casual 0 days 00:03:41            1          3.683333
# 3        casual 0 days 00:08:49            1          8.816667
# 4        casual 0 days 00:10:32            1         10.533333

# %%
mapping = {0:'Monday', 1:'Tuesday',
           2:'Wednesday', 3:'Thursday', 4:'Friday',
          5:'Saturday',6:'Sunday'}
df['day_of_week']= df['day_of_week'].replace(mapping)
df.head()
# Out:
#             ride_id  rideable_type          started_at            ended_at  \
# 0  9DC7B962304CBFD8  electric_bike 2021-09-28 16:07:10 2021-09-28 16:09:54
# 1  F930E2C6872D6B32  electric_bike 2021-09-28 14:24:51 2021-09-28 14:40:05
# 2  6EF72137900BB910  electric_bike 2021-09-28 00:20:16 2021-09-28 00:23:57
# 3  78D1DE133B3DBF55  electric_bike 2021-09-28 14:51:17 2021-09-28 15:00:06
# 4  E03D4ACDCAEF6E00  electric_bike 2021-09-28 09:53:12 2021-09-28 10:03:44
#
#   member_casual        duration day_of_week  duration_minutes
# 0        casual 0 days 00:02:44     Tuesday          2.733333
# 1        casual 0 days 00:15:14     Tuesday         15.233333
# 2        casual 0 days 00:03:41     Tuesday          3.683333
# 3        casual 0 days 00:08:49     Tuesday          8.816667
# 4        casual 0 days 00:10:32     Tuesday         10.533333

# %%
df.to_excel('202109 Cyclistic Data Processed2.xlsx')
