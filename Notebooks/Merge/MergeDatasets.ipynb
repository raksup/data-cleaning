# %%
import numpy as np
import pandas as pd

# %%
df_219 = pd.read_excel("202109 Cyclistic Data Processed.xlsx")
df_219.head()
# Out:
#    Unnamed: 0           ride_id  rideable_type          started_at  \
# 0           0  9DC7B962304CBFD8  electric_bike 2021-09-28 16:07:10
# 1           1  F930E2C6872D6B32  electric_bike 2021-09-28 14:24:51
# 2           2  6EF72137900BB910  electric_bike 2021-09-28 00:20:16
# 3           3  78D1DE133B3DBF55  electric_bike 2021-09-28 14:51:17
# 4           4  E03D4ACDCAEF6E00  electric_bike 2021-09-28 09:53:12
#
#              ended_at member_casual  duration day_of_week  duration_minutes
# 0 2021-09-28 16:09:54        casual  0.001898     Tuesday          2.733333
# 1 2021-09-28 14:40:05        casual  0.010579     Tuesday         15.233333
# 2 2021-09-28 00:23:57        casual  0.002558     Tuesday          3.683333
# 3 2021-09-28 15:00:06        casual  0.006123     Tuesday          8.816667
# 4 2021-09-28 10:03:44        casual  0.007315     Tuesday         10.533333

# %%
df_219 = df_219.drop(['Unnamed: 0', 'started_at', 'ended_at'], axis =1)
df_219.head()
# Out:
#             ride_id  rideable_type member_casual  duration day_of_week  \
# 0  9DC7B962304CBFD8  electric_bike        casual  0.001898     Tuesday
# 1  F930E2C6872D6B32  electric_bike        casual  0.010579     Tuesday
# 2  6EF72137900BB910  electric_bike        casual  0.002558     Tuesday
# 3  78D1DE133B3DBF55  electric_bike        casual  0.006123     Tuesday
# 4  E03D4ACDCAEF6E00  electric_bike        casual  0.007315     Tuesday
#
#    duration_minutes
# 0          2.733333
# 1         15.233333
# 2          3.683333
# 3          8.816667
# 4         10.533333

# %%
df_219 = df_219.drop(['rideable_type'], axis =1)
df_219.head()
# Out:
#             ride_id member_casual  duration day_of_week  duration_minutes
# 0  9DC7B962304CBFD8        casual  0.001898     Tuesday          2.733333
# 1  F930E2C6872D6B32        casual  0.010579     Tuesday         15.233333
# 2  6EF72137900BB910        casual  0.002558     Tuesday          3.683333
# 3  78D1DE133B3DBF55        casual  0.006123     Tuesday          8.816667
# 4  E03D4ACDCAEF6E00        casual  0.007315     Tuesday         10.533333

# %%
df_2110 = pd.read_excel("202110 Cyclistic Data Processed.xlsx")
df_2110.head()
# Out:
#    Unnamed: 0           ride_id  rideable_type          started_at  \
# 0           0  620BC6107255BF4C  electric_bike 2021-10-22 12:46:42
# 1           1  4471C70731AB2E45  electric_bike 2021-10-21 09:12:37
# 2           2  26CA69D43D15EE14  electric_bike 2021-10-16 16:28:39
# 3           3  362947F0437E1514  electric_bike 2021-10-16 16:17:48
# 4           4  BB731DE2F2EC51C5  electric_bike 2021-10-20 23:17:54
#
#              ended_at member_casual  duration  duration_minutes day_of_week
# 0 2021-10-22 12:49:50        member  0.002176          3.133333      Friday
# 1 2021-10-21 09:14:14        member  0.001123          1.616667    Thursday
# 2 2021-10-16 16:36:26        member  0.005405          7.783333    Saturday
# 3 2021-10-16 16:19:03        member  0.000868          1.250000    Saturday
# 4 2021-10-20 23:26:10        member  0.005741          8.266667   Wednesday

# %%
df_2110 = df_2110.drop(['Unnamed: 0', 'rideable_type', 'started_at', 'ended_at'], axis =1)
df_2110.head()
# Out:
#             ride_id member_casual  duration  duration_minutes day_of_week
# 0  620BC6107255BF4C        member  0.002176          3.133333      Friday
# 1  4471C70731AB2E45        member  0.001123          1.616667    Thursday
# 2  26CA69D43D15EE14        member  0.005405          7.783333    Saturday
# 3  362947F0437E1514        member  0.000868          1.250000    Saturday
# 4  BB731DE2F2EC51C5        member  0.005741          8.266667   Wednesday

# %%
cols = list(df_2110.columns.values)
cols
# Out:
# ['ride_id', 'member_casual', 'duration', 'duration_minutes', 'day_of_week']

# %%
df_2110 = df_2110[['ride_id', 'member_casual', 'duration', 'day_of_week', 'duration_minutes']]
df_
drop(['Unnamed: 0', 'rideable_type', 'started_at', 'ended_at'], axis =1)

# %%
df_2112 = df_2112[['ride_id', 'member_casual', 'duration', 'day_of_week', 'duration_minutes']]
df_2112.head()
# Out:
#             ride_id member_casual  duration day_of_week  duration_minutes
# 0  46F8167220E4431F        member  0.005266     Tuesday          7.583333
# 1  73A77762838B32FD        casual  0.018681    Saturday         26.900000
# 2  4CF42452054F59C5        member  0.008866   Wednesday         12.766667
# 3  3278BA87BF698339        member  0.010220      Sunday         14.716667
# 4  6FF54232576A3B73        member  0.014074    Thursday         20.266667

# %%
df_2201 = pd.read_excel("202201 Cyclistic Data Processed.xlsx")
df_2201.head()
# Out:
#    Unnamed: 0           ride_id  rideable_type          started_at  \
# 0           0  C2F7DD78E82EC875  electric_bike 2022-01-13 11:59:47
# 1           1  A6CF8980A652D272  electric_bike 2022-01-10 08:41:56
# 2           2  BD0F91DFF741C66D   classic_bike 2022-01-25 04:53:40
# 3           3  CBB80ED419105406   classic_bike 2022-01-04 00:18:04
# 4           4  DDC963BFDDA51EEA   classic_bike 2022-01-20 01:31:10
#
#              ended_at member_casual  duration  duration_minutes day_of_week
# 0 2022-01-13 12:02:44        casual  0.002049          2.950000    Thursday
# 1 2022-01-10 08:46:17        casual  0.003021          4.350000      Monday
# 2 2022-01-25 04:58:01        member  0.003021          4.350000     Tuesday
# 3 2022-01-04 00:33:00        casual  0.010370         14.933333     Tuesday
# 4 2022-01-20 01:37:12        member  0.004190          6.033333    Thursday

# %%
df_2201 = df_2201.drop(['Unnamed: 0', 'rideable_type', 'started_at', 'ended_at'], axis =1)

# %%
df_2201 = df_2201[['ride_id', 'member_casual', 'duration', 'day_of_week', 'duration_minutes']]
df_2201.head()
# Out:
#             ride_id member_casual  duration day_of_week  duration_minutes
# 0  C2F7DD78E82EC875        casual  0.002049    Thursday          2.950000
# 1  A6CF8980A652D272        casual  0.003021      Monday          4.350000
# 2  BD0F91DFF741C66D        member  0.003021     Tuesday          4.350000
# 3  CBB80ED419105406        casual  0.010370     Tuesday         14.933333
# 4  DDC963BFDDA51EEA        member  0.004190    Thursday          6.033333

# %%
df_2202 = pd.read_excel("202202 Cyclistic Data Processed.xlsx")

df_2202 = df_2202.drop(['Unnamed: 0', 'rideable_type', 'started_at', 'ended_at'], axis =1)
df_2202 = df_2202[['ride_id', 'member_casual', 'duration', 'day_of_week', 'duration_minutes']]
df_2202.head()
# Out:
#             ride_id member_casual  duration day_of_week  duration_minutes
# 0  E1E065E7ED285C02        member  0.010590    Saturday         15.250000
# 1  1602DCDC5B30FFE3        member  0.003079      Sunday          4.433333
# 2  BE7DD2AF4B55C4AF        member  0.009468      Friday         13.633333
# 3  A1789BDF844412BE        member  0.004826      Monday          6.950000
# 4  07DE78092C62F7B3        member  0.002014   Wednesday          2.900000

# %%
df_2203 = pd.read_excel("202203 Cyclistic Data Processed.xlsx")

df_2203 = df_2203.drop(['Unnamed: 0', 'rideable_type', 'started_at', 'ended_at'], axis =1)
df_2203 = df_2203[['ride_id', 'member_casual', 'duration', 'day_of_week', 'duration_minutes']]
df_2203.head()
# Out:
#             ride_id member_casual  duration day_of_week  duration_minutes
# 0  47EC0A7F82E65D52        member  0.004363      Monday          6.283333
# 1  8494861979B0F477        member  0.004375   Wednesday          6.300000
# 2  EFE527AF80B66109        member  0.001921   Wednesday          2.766667
# 3  9F446FD9DEE3F389        member  0.006806     Tuesday          9.800000
# 4  431128AD9AFFEDC0        member  0.029282      Monday         42.166667

# %%
df_2204 = pd.read_excel("202204 Cyclistic Data Processed.xlsx")

df_2204 = df_2204.drop(['Unnamed: 0', 'rideable_type', 'started_at', 'ended_at'], axis =1)
df_2204 = df_2204[['ride_id', 'member_casual', 'duration', 'day_of_week', 'duration_minutes']]
df_2204.head()
# Out:
#             ride_id member_casual  duration day_of_week  duration_minutes
# 0  3564070EEFD12711        member  0.008194   Wednesday         11.800000
# 1  0B820C7FCF22F489        member  0.014005      Sunday         20.166667
# 2  89EEEE32293F07FF        member  0.004259   Wednesday          6.133333
# 3  84D4751AEB31888D        casual  0.006516      Friday          9.383333
# 4  5664BCF0D1DE7A8B        member  0.003947    Saturday          5.683333

# %%
df_2205 = pd.read_excel("202205 Cyclistic Data Processed.xlsx")

df_2205 = df_2205.drop(['Unnamed: 0', 'rideable_type', 'started_at', 'ended_at'], axis =1)
df_2205 = df_2205[['ride_id', 'member_casual', 'duration', 'day_of_week', 'duration_minutes']]
df_2205.head()
# Out:
#             ride_id member_casual  duration day_of_week  duration_minutes
# 0  EC2DE40644C6B0F4        member  0.023160      Monday         33.350000
# 1  1C31AD03897EE385        member  0.026319   Wednesday         37.900000
# 2  1542FBEC830415CF        member  0.015162    Thursday         21.833333
# 3  6FF59852924528F8        member  0.006042     Tuesday          8.700000
# 4  483C52CAAE12E3AC        member  0.003484     Tuesday          5.016667

# %%
df_2206 = pd.read_excel("202206 Cyclistic Data Processed.xlsx")

df_2206 = df_2206.drop(['Unnamed: 0', 'rideable_type', 'started_at', 'ended_at'], axis =1)
df_2206 = df_2206[['ride_id', 'member_casual', 'duration', 'day_of_week', 'duration_minutes']]
df_2206.head()
# Out:
#             ride_id member_casual  duration day_of_week  duration_minutes
# 0  600CFD130D0FD2A4        casual  0.005116    Thursday          7.366667
# 1  F5E6B5C1682C6464        casual  0.005278    Thursday          7.600000
# 2  B6EB6D27BAD771D2        casual  0.009363    Thursday         13.483333
# 3  C9C320375DE1D5C6        casual  0.002986    Thursday          4.300000
# 4  56C055851023BE98        casual  0.005868   Wednesday          8.450000

# %%
df_2207 = pd.read_excel("202207 Cyclistic Data Processed.xlsx")

df_2207 = df_2207.drop(['Unnamed: 0', 'rideable_type', 'started_at', 'ended_at'], axis =1)
df_2207 = df_2207[['ride_id', 'member_casual', 'duration', 'day_of_week', 'duration_minutes']]
df_2207.head()
# Out:
#             ride_id member_casual  duration day_of_week  duration_minutes
# 0  954144C2F67B1932        member  0.008160     Tuesday         11.750000
# 1  292E027607D218B6        casual  0.001308     Tuesday          1.883333
# 2  57765852588AD6E0        casual  0.005359      Sunday          7.716667
# 3  B5B6BE44314590E6        casual  0.040613      Sunday         58.483333
# 4  A4C331F2A00E79E0        member  0.018264   Wednesday         26.300000

# %%
df_2208 = pd.read_excel("202208 Cyclistic Data Processed.xlsx")

df_2208 = df_2208.drop(['Unnamed: 0', 'rideable_type', 'started_at', 'ended_at'], axis =1)
df_2208 = df_2208[['ride_id', 'member_casual', 'duration', 'day_of_week', 'duration_minutes']]
df_2208.head()
# Out:
#             ride_id member_casual  duration day_of_week  duration_minutes
# 0  550CF7EFEAE0C618        casual  0.005220      Sunday          7.516667
# 1  DAD198F405F9C5F5        casual  0.009745      Monday         14.033333
# 2  E6F2BC47B65CB7FD        casual  0.007454      Monday         10.733333
# 3  F597830181C2E13C        casual  0.010451      Monday         15.050000
# 4  0CE689BB4E313E8D        casual  0.004074      Sunday          5.866667

# %%
merged_df = pd.concat([df_219, df_2110, df_2111, 
                       df_2112, df_2201, df_2202,
                       df_2203, df_2204, df_2205,
                       df_2206, df_2207, df_2208])
merged_df.head()
# Out:
#             ride_id member_casual  duration day_of_week  duration_minutes
# 0  9DC7B962304CBFD8        casual  0.001898     Tuesday          2.733333
# 1  F930E2C6872D6B32        casual  0.010579     Tuesday         15.233333
# 2  6EF72137900BB910        casual  0.002558     Tuesday          3.683333
# 3  78D1DE133B3DBF55        casual  0.006123     Tuesday          8.816667
# 4  E03D4ACDCAEF6E00        casual  0.007315     Tuesday         10.533333

# %%
merged_df.to_csv('cyclistic_all_2109_to_2209.csv', encoding='utf-8')

# %%
df = pd.read_csv('cyclistic_all_2109_to_2209.csv')
df.head()
# Out:
#    Unnamed: 0           ride_id member_casual  duration day_of_week  \
# 0           0  9DC7B962304CBFD8        casual  0.001898     Tuesday
# 1           1  F930E2C6872D6B32        casual  0.010579     Tuesday
# 2           2  6EF72137900BB910        casual  0.002558     Tuesday
# 3           3  78D1DE133B3DBF55        casual  0.006123     Tuesday
# 4           4  E03D4ACDCAEF6E00        casual  0.007315     Tuesday
#
#    duration_minutes
# 0          2.733333
# 1         15.233333
# 2          3.683333
# 3          8.816667
# 4         10.533333
